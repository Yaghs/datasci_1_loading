# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaghs/datasci_1_loading/blob/main/HHA_507_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %% [markdown]
# **THE CELL BELOW IS ASSIGINING THE CSV FILES FROM THEIR RELATIVE PATHS TO THE FOLLOWING VARIABLES csv_data1, csv_data2, csv_data3**

# %%
csv_data1 = '/content/Data/CSV_files/Inpatient_Rehabilitation_Facility-General_Information_Jun2026_b.csv'
csv_data2 = '/content/Data/CSV_files/Inpatient_Rehabilitation_Facility-National_Data_Jun2026_b.csv'
csv_data3 = '/content/Data/CSV_files/Inpatient_Rehabilitation_Facility-Provider_Data_Jun2026_b.csv'

# %% [markdown]
# **THE CELL BELOW IS ASSIGNING THE XLSX FILES TO FROM THEIR RELATIVE PATHS TO THE FOLLOWING VARIABLES: xlsx_data1, xlsx_data2, xlsx_data3**

# %%
xlsx_data1 = '/content/Data/XLSX_files/CPI-forecast.xlsx'
xlsx_data2 = '/content/Data/XLSX_files/CPI-historical-forecast.xlsx'
xlsx_data3 = '/content/Data/XLSX_files/PPI-historical-forecast.xlsx'

# %% [markdown]
# **THE CELL BELOW IS ASSIGNING THE JSON FILES FROM THEIR RELATIVE PATHS TO THE FOLLOWING VARIABLES: json_data1, json_data2, json_data3**

# %%
json_data1 = '/content/Data/JSON_files/MTA-headcount-2024.json'
json_data2 = '/content/Data/JSON_files/MTA-subway-delays-2020.json'
json_data3 = '/content/Data/JSON_files/retail-food-stores.json'

# %% [markdown]
# **csv_data1 represents the following:**
#
# blablabla

# %% [markdown]
# **bold text**
